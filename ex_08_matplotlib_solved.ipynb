# %% [markdown]
# | **Kinga Węzka** <BR> kinga.wezka@pw.edu.pl  <BR> Warsaw University of Technology <BR> Faculty Geodesy and Cartography <BR> Plac Politechniki 1 (room 38)<BR> 00-661 Warszawa, POLAND<BR> <A href="https://www.google.com/maps/place/Gmach+G%C5%82%C3%B3wny+Politechniki+Warszawskiej/@52.220656,21.0094422,19z/data=!3m1!4b1!4m5!3m4!1s0x471ecce951c85a19:0x712b0e1503c42b91!8m2!3d52.220656!4d21.0099894"> N 52&ordm; 12' 45&quot; / E 21&ordm; 03' 51&quot;</A></B><BR> | <a rel="license" href="https://www.pw.edu.pl"><img alt="Politechnika Warszawska" style="border-width:0" src="https://www.pw.edu.pl/design/pw/images/znak-pw.png" /></a> |
# |---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
#
# **Informatyka Geodezyjna** (projekt) -- rok akademicki 2020/2021
#
# **Prowadzący:** Kinga Węzka, Joanna Kożuchowska
#
# **Projekt 9** graficzna prezentacja wyników - biblioteka **matplotlib**
#
# **UWAGA: Odpowiedź na każde pytanie powinna znajdować się w oddzielnej komórce poniżej pytania, z podanym numerem pytania**

# %% [markdown]
# # Spis treści:
#
# 1. [Zad. 1: Wyświetlanie wykresów - backend](#zad1)
# 2. [Zad. 2: Wykres Polygon](#zad2)
# 3. [Zad. 3: Wiele zestawów danych na jednym wykresie ](#zad3)
# 4. [Zad. 4: Wiele wykresów w jednym obiekcie (subfigure)](#zad4)
# 5. [Zad. 5: Wykres słupkowy (bar)](#zad5)
# 6. [Zad. 6: Wykres histogram (hist)](#zad6)
# 7. [Zad. 7: Cartopy](#zad7)
# 8. [Zad. 8: Mapa Polski na podstawie danych granic administracyjnych](#zad8)

# %% [markdown]
# ## Zad.1: Wyświetlanie wykresów - backend <a name="zad1"></a>
#
# Zdefiniować sposób wyświetlania wykresów matplotlib w JupyterNotebook (jeśli wykorzystywane)

# %%
import matplotlib.pyplot as plt

#wyswietlenie w lini komórki Jupyter 
# %matplotlib inline

#wyświetlanie w lini z opcjami interaktywnymi:
#%matplotlib notebook

#wyświetlenie w domyślnym oknie interaktywnym
#%matplotlib

#wyświetlenie w wybranym oknie interaktywnym:  qt, wx, gtk, osx, tk, empty uses default
#%matplotlib qt


# Przykład  
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['lines.linewidth'] = 1
mpl.rcParams['lines.linestyle'] = '-.'
mpl.rcParams['xtick.labelsize'] = 16
mpl.rcParams['ytick.labelsize'] = 16
mpl.rcParams['axes.titlesize'] = 16
mpl.rcParams['axes.labelsize'] = 16
mpl.rcParams['axes.grid'] = True


import random 
x = range(64)
y = [random.randint(0, 10) for i in range(64)]
y1 = [random.randint(0, 5) for i in range(64)]

# utworzenie obiektu Figure(fig) i obiektów Axes(ax1, ax2)
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 3))

# 1szy wykres
ax1.plot(y, 'x-', color = 'red', label = 'dane y')
ax1.plot(y1, ':', color = 'blue', label = 'dane y1')
ax1.set_title('y(x)')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.legend(loc = 'upper left')

# 2gi wykres:
for i in range(len(y)):
    if y[i] > 5:
        ax2.scatter(x[i], y[i], marker = 'x', color = 'green')
    if y[i] <= 5:
        ax2.scatter(x[i], y[i], marker = 'x', color = 'red')  
ax2.set_title('y(x)')
ax2.set_xlabel('x')
ax2.set_ylabel('y')

plt.show()
fig.savefig('nazwa.png', format='png', box_inches='tight', pad_inches=0.01, dpi=72)

# %% [markdown]
# ## Zad.2: Wykres  Polygon <a name="zad2"></a>
#
# a) Narysować wykres y(x) (połączony linią) na podstawie dwóch dziesięcioelementowych list A i B. Dodać tytuł wykresu i opisy osi.
#
# b) Zmienić rozmiar wykresu na długość 10 i wysokość 8.
#
# c) Zmienić sposób wyświetlania wykresu na czerwone kółeczka.
#
# d) Zrealizowac podpunkt c), korzystając z polecenia scatter.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

pts = np.array([[2,2], [6,5], [3,5]])

fig, ax 

p = Polygon(pts, closed=False)
ax = plt.gca()
ax.add_patch(p)
ax.set_xlim(1,7)
ax.set_ylim(1,8)
plt.show()

# %%
#b
fig = plt.figure(figsize = (5, 3))
ax  = fig.add_subplot(111)
A   = [0, 1, 2, 0]
B   = [0, 1, 2, 0]
ax.scatter(A, B, marker ='x')
ax.set_title('y(x)')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# %%
#c
fig = plt.figure(figsize = (5, 3))
ax  = fig.add_subplot(111)
ax.plot(A, B, 'ro')
ax.set_title('y(x)')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# %%
#d
fig = plt.figure(figsize = (5, 3))
ax  = fig.add_subplot(111)
ax.scatter(A, B, c= 'r', marker = 'o')
ax.set_title('y(x)')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# %% [markdown]
# ## Zad.3: Wiele zestawów danych na jednym wykresie <a name="zad3"></a>
# a) Narysować na jednym wykresie dwa zestawy danych (wykorzystując jedno polecenie plot). Na pierwszym z wykresów zamieścić y(x) z zadania 1, na drugim funkcję g(x), gdzie x obliczone zostanie dla 7 równomiernie rozłożonych wartości z przedziału <0, 10>, a $g(x) = x^2 + 3$.
#
# b) Narysować na jednym wykresie dwa zestawy danych (te same, co w zadaniu 1) i umieścić legendę.
# Podpowiedź: skorzystać z dwóch poleceń plot.

# %%
#a
import numpy as np

x = np.linspace(0, 10, 7)
gx = [i**2 +3 for i in x]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(A, B, 'r', x, gx, 'g-.')
ax.set_title('y(x)')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# %%
#b
import numpy as np

x = np.linspace(0, 10, 7)
gx = [i**2 +3 for i in x]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(A, B, 'r', label = 'f(x)')
ax.plot(x, gx, 'g-.', label='g(x)')
ax.legend()
ax.set_title('y(x)')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# %% [markdown]
# ## Zad.4: Wiele wykresów w jednym obiekcie (subfigure) <a name="zad4"></a>
#
# Narysować dwa podwykresy w jednym obiekcie figure. Na pierwszym wykresie umieścić dane z list z zadania 1, na drugim narysować przebieg funkcji kwadratowej w przedziale <-5, 5>. Dodać tytuł dla obu podwykresów oraz dla zestawu wykresów. Do punktów a i b wykorzystać add_subplot()
#
# a) Wykresy ustawić w dwóch kolumnach.
#
# b) Wykresy ustawić w dwóch wierszach.
#
# c) Zrealizować zadanie a i b zadanie korzystając z plt.subplots() lub plt.subplot()

# %%
#a
x = range(-5, 6)
gx = [i**2 for i in x]

fig = plt.figure()
ax1 = fig.add_subplot(121)
ax1.plot(A, B, 'r')
ax1.set_title('y')
ax1.set_xlabel('x')
ax1.set_ylabel('f(x)')

ax2 = fig.add_subplot(122)
ax2.plot(x, gx, 'g-.')
ax2.set_title('y')
ax2.set_xlabel('x')
ax2.set_ylabel('g(x)')
fig.suptitle('Dwa wykresy w jednym figure')

plt.show()

# %%
# b
import matplotlib.pyplot as plt
x = range(-5, 6)
gx = [i**2 for i in x]

fig = plt.figure()

ax1 = fig.add_subplot(211)
ax1.plot(A, B, 'r')
ax1.set_title('f(x)')
ax1.set_xlabel('x')
ax1.set_ylabel('y')

ax2 = fig.add_subplot(212)
ax2.plot(x, gx, 'g-.')
ax2.set_title('g(x)')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
fig.suptitle('Dwa wykresy')
plt.show()

# %%
# c
import matplotlib.pyplot as plt
x = range(-5, 6)
gx = [i**2 for i in x]
A = range(10)
B = [a/2 for a in A]

fig, array_axes = plt.subplots(2, 1)
array_axes[0].plot(A, B, 'r')
array_axes[0].set_title('f(x)')
array_axes[0].set_xlabel('x')
array_axes[0].set_ylabel('y')
array_axes[1].plot(x, gx, 'g-.')
array_axes[1].set_title('g(x)')
array_axes[1].set_xlabel('x')
array_axes[1].set_ylabel('y')
fig.suptitle('Dwa wykresy w jednym figure')

plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


x = range(-5, 6)
gx = [i**2 for i in x]
A = range(10)
B = [a/2 for a in A]


fig, (ax0, ax1) = plt.subplots(nrows=1,ncols=2, sharey=True, figsize=(7, 4))
fig.suptitle('2014 Sales Analysis', fontsize=14, fontweight='bold');

ax0.set(title='wykres', xlabel='xlabel A', ylabel='cos')
ax0.plot(A,B, 'bo')

ax1.set(title='inny wykres', xlabel='xlabel B', ylabel='ycos')
ax1.plot(A, B, 'ro')


plt.show()

# %% [markdown]
# ## Zad.5: Wykres słupkowy (bar) <a name="zad5"></a>
# a) Narysować wykres słupkowy, na którym zostaną przedstawione dane dotyczące dziennego zapotrzebowania wartości odżywczych w jakimś produkcie (np. 1 cytryna to 90% dziennego zapotrzebowania na witamine C).
# Zmodyfikować kolor słupków. Zamieścić opis prezentowanych danych.
#
# b) Narysować ten sam wykres, tym razem słupki zamieszczając poziomo.

# %%
#a
skladniki = ['tluszcz', 'bialko', 'cukry', 'sod', 'blonnik', 'wit C', 'wit E', 'kwas foliowy']
wartosci = [44, 9, 2, 1, 54, 43, 24, 37]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(skladniki, wartosci, color='green')
ax.set_title('Dzienne zapotrzebowanie w 1 awokado')
ax.set_ylabel('%')
ax.set_xlabel('skladniki odzywcze')
plt.show()

# %%
#b
skladniki = ['tluszcz', 'bialko', 'cukry', 'sod', 'blonnik', 'wit C', 'wit E', 'kwas foliowy']
wartosci = [44, 9, 2, 1, 54, 43, 24, 37]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.barh(skladniki, wartosci, color='green')
ax.set_title('Dzienne zapotrzebowanie w 1 awokado')
ax.set_xlabel('%')
ax.set_ylabel('skladniki odzywcze')
plt.show()

# %% [markdown]
# ## Zad.6: Wykres histogram (hist) <a name="zad6"></a>
# Stworzyć histogram z losowo wygenerowanych danych. Zapisać wykres do pliku

# %%
import numpy as np
x = np.random.randn(1000)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title("histogram")
ax.hist(x, 100)
plt.show()



fig.savefig('histogram.png',format='png', box_inches='tight', pad_inches=0.01, dpi=72)

# %% [markdown]
# ## Zad. 7: Cartopy <a name="zad7"></a>
# Korzystając z biblioteki cartopy, wczytać plik shp zawierający granice dowolnego kraju (innego niż Polska, o powierzchni większej niż 10 000 km^2). Zaznacz na mapie stolicę tego kraju, na przykład za pomocą kółeczka lub trójkąta (i dodaj jej nazwę).

# %%
# %matplotlib inline
import cartopy

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import cartopy.io.img_tiles as cimgt

import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
def map_poland():
    
    fig = plt.figure()

    ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
    ax.coastlines()
    ax.set_extent([13.5, 24, 48, 55] )  #  (x0, x1, y0, y1):  (East, Weast, South, North)
#    ax.add_feature(cfeature.LAND)
    ax.add_feature(cfeature.OCEAN)
#    ax.add_feature(cfeature.COASTLINE)
    ax.add_feature(cfeature.BORDERS, linestyle=':')
    ax.add_feature(cfeature.LAKES, alpha=0.5)
    ax.add_feature(cfeature.RIVERS)
    
    Warsaw_lon, Warsaw_lat = 52.0, 21.0
    plt.scatter(Warsaw_lat, Warsaw_lon , color='red', marker='o', transform=ccrs.Geodetic())
  
    # ustawienia osi współrzędnych
    gl = ax.gridlines(crs=ccrs.PlateCarree(), linewidth=0.5, color='black', alpha=0.5, linestyle='--', draw_labels=True)
    gl.xlabels_top = False
    gl.ylabels_left = False
    gl.ylabels_right=True
    gl.xlines = True
    gl.xlocator = mticker.FixedLocator([12, 14, 16, 18, 20, 22, 24])
    gl.ylocator = mticker.FixedLocator([48, 49, 50, 51, 52, 52, 53, 54])
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    gl.xlabel_style = {'color': 'red', 'weight': 'bold'}
    
    plt.savefig('PL.png')
    plt.show()
    

if __name__ == '__main__':
    map_poland()

# %% [markdown]
# ## Zad. : Mapa Polski na podstawie danych granic administracyjnych <a name="zad8"></a>
#
# Narysować mapę Polski z granicami administracyjnymi województw i powiatów.
#
# Pliki shape, z granicami administracyjnymi kraju można pobrać na stronie: https://gadm.org/download_country_v3.html

# %%
# %matplotlib inline
import cartopy.crs as ccrs
import cartopy.io.shapereader as shpreader
import matplotlib.pyplot as plt

# wczytanie pliku shape, 
# pliki shape można pobrać na stronie: https://gadm.org/download_country_v3.html
fname = "maps_gadm36_POL_shp/gadm36_POL_0.shp" # granice kraju
fname = "maps_gadm36_POL_shp/gadm36_POL_1.shp" # granice kraju + województwa
fname = "maps_gadm36_POL_shp/gadm36_POL_2.shp" # granice kraju + województwa + powiaty
fname = "maps_gadm36_POL_shp/gadm36_POL_3.shp" # granice kraju + województwa + powiaty  + gminy

plt.figure(figsize=(12, 8))  # inicjalizacja wykresu
ax = plt.axes(projection=ccrs.Mercator())

east    = 13.8
west    = 24.2
north   = 55
south   = 48.5
ax.set_extent([west, east, south, north], ccrs.Mercator())

adm1_shapes = list(shpreader.Reader(fname).geometries())
shp = shpreader.Reader(fname)

woj = ('Zachodniopomorskie', 'Mazowieckie', 'Małopolskie') # lista województw do pokolorowania
for record, state in zip(shp.records(), shp.geometries()):
    name = record.attributes['NAME_1'] # nazwy województw
    if name in woj:
        facecolor = 'DarkOrange'
    else:
        facecolor = 'LightGray'
    # rysowanie 
    ax.add_geometries([state], 
                      ccrs.Mercator(), 
                      facecolor=facecolor, 
                      edgecolor='black',
                      alpha=0.5)
plt.show()
